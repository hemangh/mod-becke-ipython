# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from pandas import DataFrame
import matplotlib.gridspec as gridspec
import math as mt
os.chdir('/Users/hng5/ProgramDev/gridcheck/build')

# %%
fig = plt.figure(figsize=(30, 20))
gs = gridspec.GridSpec(3, 4,
                       width_ratios=[1,1,1,1.2],hspace=0.5
                       )

w, h = 4, 3;
dat = [[0 for x in range(w)] for y in range(h)] 
k = 0
for i in range(1,4):

    for j in range(1,5):

        #dat[i-1][j-1]='dat'+str(i)+str(j)
        dat[i-1][j-1]=pd.read_csv('./Alpha_lmax_exp_'+str(j)+'R_'+str(i)+'.0.txt', delimiter = ',')
        dat[i-1][j-1].set_index('    lmax',inplace=True)
        #print(dat[i-1][j-1].head())
        ax = plt.subplot(gs[k])
        k = k + 1
        if(j == 4):
            pcm = ax.pcolor(dat[i-1][j-1],
                   norm=colors.LogNorm(vmin=1E-13, vmax=1.E-1),
                   cmap='PuBu_r')
            plt.colorbar(pcm,extend='max')
        else:    
            ax.pcolor(dat[i-1][j-1],
                   norm=colors.LogNorm(vmin=1E-13, vmax=1.E-1),
                   cmap='PuBu_r')
        ax.set_title('$R$='+str(i)+'  $n$='+str(j),fontsize=24)
        ax.set_xticks(np.arange(0.5, len(dat[i-1][j-1].columns), 1))
        ax.set_xticklabels(dat[i-1][j-1].columns,rotation=90)
        ax.set_yticks(np.arange(0.5, len(dat[i-1][j-1].index), 1))
        ax.set_yticklabels(dat[i-1][j-1].index[0:])
        ax.set_xlabel(r'$\alpha$',fontsize=20)
        ax.set_ylabel("lmax",fontsize=20)
        
            
plt.savefig('Fig-powers1to4.pdf', bbox_inches='tight')
#print(dat)

# %%
print(dat[0][0].head(11))
# Out:
#                 99.106        18.052         4.886         3.780  \
#     lmax
# 7         2.163700e-09  4.078400e-09  5.862900e-10  1.259800e-10
# 9         3.189700e-11  9.244800e-11  4.462000e-11  4.980500e-11
# 11        3.019800e-12  3.126400e-11  8.446600e-11  9.378100e-11
# 15        2.620100e-12  3.138600e-11  8.310000e-11  9.307000e-11
# 17        2.908800e-12  3.128600e-11  8.310000e-11  9.304800e-11
# 19        2.353700e-12  3.136400e-11  8.312200e-11  9.307000e-11
# 21        1.965100e-12  3.134200e-11  8.310000e-11  9.305900e-11
# 23        3.441700e-12  3.165200e-11  8.310000e-11  9.307000e-11
# 29        3.586000e-12  3.138600e-11  8.310000e-11  9.307000e-11
# 31        1.843000e-12  3.189700e-11  8.317800e-11  9.310300e-11
# 35        4.640700e-12  3.175200e-11  8.311100e-11  9.308100e-11
#
#                  0.878         0.286   130.709        23.809         6.444  \
#     lmax
# 7         3.945700e-11  4.347600e-11   0.00022  1.827300e-09  5.173200e-10
# 9         1.389200e-10  8.260100e-11   0.00022  5.591100e-11  3.276300e-11
# 11        1.330700e-10  8.172400e-11   0.00022  9.063900e-11  3.096400e-11
# 15        1.331200e-10  8.172400e-11   0.00022  9.046100e-11  3.058700e-11
# 17        1.331200e-10  8.172400e-11   0.00022  9.028300e-11  3.062000e-11
# 19        1.331200e-10  8.172400e-11   0.00022  9.039400e-11  3.065300e-11
# 21        1.331200e-10  8.172400e-11   0.00022  9.008300e-11  3.066400e-11
# 23        1.331200e-10  8.172400e-11   0.00022  9.001700e-11  3.068700e-11
# 29        1.331200e-10  8.172400e-11   0.00022  9.037200e-11  3.072000e-11
# 31        1.331200e-10  8.172400e-11   0.00022  8.979500e-11  3.062000e-11
# 35        1.331200e-10  8.172400e-11   0.00022  9.015000e-11  3.082000e-11
#
#                  5.033         1.170         0.380
#     lmax
# 7         1.661100e-10  3.023100e-11  6.839000e-12
# 9         3.587100e-11  1.259800e-10  3.728100e-11
# 11        5.335700e-11  1.211700e-10  3.639300e-11
# 15        5.273600e-11  1.212400e-10  3.639300e-11
# 17        5.272400e-11  1.212400e-10  3.639300e-11
# 19        5.274700e-11  1.212400e-10  3.639300e-11
# 21        5.272400e-11  1.212400e-10  3.639300e-11
# 23        5.272400e-11  1.212400e-10  3.639300e-11
# 29        5.272400e-11  1.212500e-10  3.639300e-11
# 31        5.274700e-11  1.212400e-10  3.639300e-11
# 35        5.275800e-11  1.212500e-10  3.639300e-11

# %%
datC=pd.read_csv('./Alpha_lmaxC_exp_4R_2.0.txt', delimiter = ',')
print(datC.head())
datC.set_index('    lmax',inplace=True)

pcm = plt.pcolor(datC,norm=colors.LogNorm(vmin=min(datC.min(axis = 0) ), vmax=max(datC.max(axis = 0) )),cmap='PuBu_r')
plt.colorbar(pcm,extend='max')
#plt.set_title('$R$=2  $n$=4',fontsize=24)
plt.xticks(np.arange(0.5, len(datC.columns), 1),datC.columns,rotation=90,fontsize=14)
#plt.xlabel(datC.columns,rotation=90)
plt.yticks(np.arange(0.5, len(datC.index), 1),datC.index[0:])
#plt.ylabel(datC.index[0:])
plt.xlabel(r'$\alpha$',fontsize=20)
plt.ylabel("lmax",fontsize=20)
plt.savefig('Fig-centralReduc.pdf', bbox_inches='tight')
# Out:
#        lmax        99.106        18.052         4.886         3.780  \
# 0        47  2.350300e-11  4.624300e-10  2.916200e-06  3.823200e-06
# 1        53  4.241100e-12  1.138600e-10  6.513700e-08  7.285600e-07
# 2        59  3.641500e-12  4.387600e-11  1.066600e-07  2.095000e-07
# 3        65  3.519400e-12  8.282300e-12  1.619500e-08  1.014000e-08
# 4        71  3.497200e-12  3.108600e-13  5.631100e-11  3.688200e-09
#
#           0.878         0.286       130.709        23.809         6.444  \
# 0  1.887500e-06  4.913300e-06  7.752800e-06  5.963300e-06  4.286300e-08
# 1  1.260600e-06  1.207400e-06  2.395900e-06  6.138500e-07  3.650200e-08
# 2  5.732900e-07  2.264900e-07  4.176800e-07  2.244300e-08  7.877900e-09
# 3  9.764000e-08  2.275000e-08  2.767800e-07  1.032000e-09  2.734100e-09
# 4  9.001800e-09  1.286500e-09  4.632700e-07  1.183700e-10  3.711300e-10
#
#           5.033         1.170         0.380
# 0  2.071400e-06  5.767900e-06  5.641000e-06
# 1  3.838500e-07  1.521600e-06  1.105600e-06
# 2  3.597500e-08  4.560200e-08  1.282700e-07
# 3  1.188200e-09  3.854600e-08  2.753800e-09
# 4  6.228800e-10  8.346100e-09  9.592500e-10

# %%
min(datC.min(axis = 0) )
#datC.max(axis = 1)
# Out:
# 3.1086e-13

# %%
max(datC.max(axis = 0) )
# Out:
# 7.7528e-06

# %%
print(datC.head(9))
# Out:
#                 99.106        18.052         4.886         3.780  \
#     lmax
# 47        2.350300e-11  4.624300e-10  2.916200e-06  3.823200e-06
# 53        4.241100e-12  1.138600e-10  6.513700e-08  7.285600e-07
# 59        3.641500e-12  4.387600e-11  1.066600e-07  2.095000e-07
# 65        3.519400e-12  8.282300e-12  1.619500e-08  1.014000e-08
# 71        3.497200e-12  3.108600e-13  5.631100e-11  3.688200e-09
# 77        3.486100e-12  9.770000e-13  3.728100e-10  8.457700e-10
# 83        3.486100e-12  1.154600e-12  6.668000e-11  6.190600e-11
# 89        3.486100e-12  1.176800e-12  5.773200e-13  1.706400e-11
# 95        3.486100e-12  1.187900e-12  6.161700e-12  1.572100e-11
#
#                  0.878         0.286       130.709        23.809  \
#     lmax
# 47        1.887500e-06  4.913300e-06  7.752800e-06  5.963300e-06
# 53        1.260600e-06  1.207400e-06  2.395900e-06  6.138500e-07
# 59        5.732900e-07  2.264900e-07  4.176800e-07  2.244300e-08
# 65        9.764000e-08  2.275000e-08  2.767800e-07  1.032000e-09
# 71        9.001800e-09  1.286500e-09  4.632700e-07  1.183700e-10
# 77        4.691400e-10  9.587900e-11  2.789200e-07  6.972200e-12
# 83        1.830800e-11  1.154600e-11  7.892100e-08  2.053900e-12
# 89        5.421200e-11  5.981900e-11  1.609800e-08  2.509100e-12
# 95        6.897800e-11  3.119700e-11  4.251200e-08  1.720800e-12
#
#                  6.444         5.033         1.170         0.380
#     lmax
# 47        4.286300e-08  2.071400e-06  5.767900e-06  5.641000e-06
# 53        3.650200e-08  3.838500e-07  1.521600e-06  1.105600e-06
# 59        7.877900e-09  3.597500e-08  4.560200e-08  1.282700e-07
# 65        2.734100e-09  1.188200e-09  3.854600e-08  2.753800e-09
# 71        3.711300e-10  6.228800e-10  8.346100e-09  9.592500e-10
# 77        2.966500e-11  5.160300e-11  8.407400e-10  3.428400e-11
# 83        1.609800e-12  8.026900e-12  6.745700e-11  6.106200e-12
# 89        3.919100e-12  9.303700e-12  4.922700e-11  1.877400e-11
# 95        4.185500e-12  8.759700e-12  6.221700e-11  2.893200e-11

# %%
datBecke=pd.read_csv('./Alpha_rmax_exp_4L_47.txt', delimiter = ',')
print(datBecke.head())
datBecke.set_index('    rmax',inplace=True)


datNico=pd.read_csv('./Alpha_rmax_L_47.txt', delimiter = ',')
print(datNico.head())
datNico.set_index('    rmax',inplace=True)


fig = plt.figure(figsize=(20, 7))
gs = gridspec.GridSpec(1, 2,
                       width_ratios=[1,1.2]
                       )

ax1 = plt.subplot(gs[0])
#ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[1])
#ax4 = plt.subplot(gs[3])

ax1.pcolor(datBecke,
                   norm=colors.LogNorm(vmin=1E-13, vmax=1.E-1),
                   cmap='PuBu_r')
ax1.set_title('Becke',fontsize=24)
ax1.set_xticks(np.arange(0.5, len(datBecke.columns), 1))
ax1.set_xticklabels(datBecke.columns,rotation=90)
ax1.set_yticks(np.arange(0.5, len(datBecke.index), 1))
ax1.set_yticklabels(datBecke.index[0:])
#ax1.set_xlabel(r'$\alpha$',fontsize=20)
ax1.set_ylabel("Rmax",fontsize=20)


pcm=ax3.pcolor(datNico,
                   norm=colors.LogNorm(vmin=1E-13, vmax=1.E-1),
                   cmap='PuBu_r')
ax3.set_title('Modified Becke',fontsize=24)
ax3.set_xticks(np.arange(0.5, len(datNico.columns), 1))
ax3.set_xticklabels(datNico.columns,rotation=90)
ax3.set_yticks(np.arange(0.5, len(datNico.index), 1))
ax3.set_yticklabels(datNico.index[0:])
#ax3.set_xlabel(r'$\alpha$',fontsize=20)

plt.colorbar(pcm,extend='max')
# Out:
#        rmax        99.106        18.052         4.886         3.780  \
# 0       5.0  1.190300e-08  8.338900e-10  7.551700e-11  5.773200e-12
# 1       6.0  1.190400e-08  8.354200e-10  7.598400e-11  2.264900e-12
# 2       7.0  6.410300e-09  4.375200e-10  1.834100e-11  3.320700e-11
# 3       8.0  3.164000e-09  1.714900e-10  2.063900e-11  4.354300e-11
# 4       9.0  1.665500e-09  9.776600e-11  2.988700e-11  6.177300e-11
#
#           0.878     0.286       130.709        23.809         6.444  \
# 0  1.686700e-03  2.076600  1.708900e-09  3.742000e-09  2.702300e-11
# 1  1.515100e-05  0.460110  1.706900e-09  3.746400e-09  2.911000e-11
# 2  5.336500e-08  0.081200  4.769200e-09  1.046200e-08  7.367400e-11
# 3  1.260900e-09  0.010782  1.200500e-08  2.062700e-08  5.183600e-11
# 4  9.955400e-11  0.001066  2.156300e-08  2.722400e-08  4.090100e-11
#
#           5.033         1.170     0.380
# 0  1.623800e-10  1.314200e-04  1.049700
# 1  1.619000e-10  4.411600e-07  0.148070
# 2  4.118900e-11  5.956000e-09  0.015039
# 3  4.418700e-12  5.630200e-10  0.001043
# 4  5.383500e-11  7.615700e-10  0.000049
#        rmax        99.106        18.052         4.886         3.780  \
# 0       5.0  1.190300e-08  8.338900e-10  7.551700e-11  5.773200e-12
# 1       6.0  1.190400e-08  8.354200e-10  7.598400e-11  2.264900e-12
# 2       7.0  6.410300e-09  4.375200e-10  1.834100e-11  3.320700e-11
# 3       8.0  3.164000e-09  1.714900e-10  2.063900e-11  4.354300e-11
# 4       9.0  1.665500e-09  9.776600e-11  2.988700e-11  6.177300e-11
#
#           0.878     0.286       130.709        23.809         6.444  \
# 0  1.686700e-03  2.076600  1.708900e-09  3.742000e-09  2.702300e-11
# 1  1.515100e-05  0.460110  1.706900e-09  3.746400e-09  2.911000e-11
# 2  5.336500e-08  0.081200  4.769200e-09  1.046200e-08  7.367400e-11
# 3  1.260900e-09  0.010782  1.200500e-08  2.062700e-08  5.183600e-11
# 4  9.955400e-11  0.001066  2.156300e-08  2.722400e-08  4.090100e-11
#
#           5.033         1.170     0.380
# 0  1.623800e-10  1.314200e-04  1.049700
# 1  1.619000e-10  4.411600e-07  0.148070
# 2  4.118900e-11  5.956000e-09  0.015039
# 3  4.418700e-12  5.630200e-10  0.001043
# 4  5.383500e-11  7.615700e-10  0.000049
